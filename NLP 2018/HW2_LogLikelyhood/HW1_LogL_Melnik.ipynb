# %% [markdown]
# # Keywords search

# %%
import lxml
import xml.etree.ElementTree as ET
import string
import nltk
from nltk.tokenize import word_tokenize
import string
import pymorphy2
import stop_words
from stop_words import get_stop_words
import pandas as pd
import loglikelihood
import numpy

# %%
def get_corpus(file_name):
    
    tree = ET.parse(file_name)
    root = tree.getroot()
    
    texts = ''
    for corpus in root:
        for unit in corpus:
            if unit.tag == 'body':
                texts += unit.text
                
    return texts

# %%
def preprocessing(text):
    morph = pymorphy2.MorphAnalyzer()
    text = ''.join([i for i in text if i not in set(string.punctuation)])
    text = text.lower()
    words = word_tokenize(text)
    lemmas = []
    for word in words:
        lemmas.append(morph.parse(word)[0].normal_form)
    lemmas = [i for i in lemmas if i not in get_stop_words('ru')]
    return lemmas

# %% [markdown]
# Возьмем два корпуса:
#     - RefC - тематический корпус
#     - SpecC - контрастный корпус

# %% [markdown]
# И проведем некоторую предобработку:
#     - удаление пунктуации
#     - приведение к нижнему регистру
#     - токенизация
#     - лемматизация

# %%
RefC = get_corpus('reference_corpus.xml')
SpecC = get_corpus('corpus_pravoslavnyh_tekstov.xml')

# %%
RefC_lemm = preprocessing(RefC)
SpecC_lemm = preprocessing(SpecC)

# %%
lenRefC = len(RefC_lemm)
lenSpecC = len(SpecC_lemm)
lenC = lenRefC + lenSpecC
C_lemm = RefC_lemm + SpecC_lemm

# %% [markdown]
# Частотный словник (наблюдаемые статистики и ожидаемые частоты):

# %%
bow = set(C_lemm)
bow_Series = pd.Series(list(bow))

# %%
df = pd.DataFrame({'word' : bow_Series,
                             'word freq in SpecC' : bow_Series.apply(SpecC_lemm.count),
                             'word freq in RefC' : bow_Series.apply(RefC_lemm.count)})
df['word freq in C'] = df['word freq in RefC'] + df['word freq in SpecC']
df['not word freq in RefC'] = lenRefC - df['word freq in RefC']
df['not word freq in SpecC'] = lenSpecC - df['word freq in SpecC']
df['not word freq in C'] = lenC - df['word freq in C']
df['expected freq in SpecC'] = lenSpecC * (df['word freq in C'] / (lenC))
df['expected freq in RefC'] = lenRefC * (df['word freq in C'] / (lenC))

# %%
df.head()
# Out:
#             word  word freq in RefC  word freq in SpecC  word freq in C  \
# 0       делаться                  3                   1               4
# 1           двое                  0                   6               6
# 2  настроенность                  0                   1               1
# 3     советовать                  2                   0               2
# 4        материя                  0                   2               2
#
#    not word freq in RefC  not word freq in SpecC  not word freq in C  \
# 0                   6058                    5928               11986
# 1                   6061                    5923               11984
# 2                   6061                    5928               11989
# 3                   6059                    5929               11988
# 4                   6061                    5927               11988
#
#    expected freq in SpecC  expected freq in RefC
# 0                1.977982               2.022018
# 1                2.966972               3.033028
# 2                0.494495               0.505505
# 3                0.988991               1.011009
# 4                0.988991               1.011009

# %% [markdown]
# Применим статистику **Loglikelihood**.

# %% [markdown]
# #### $Loglikelihood = 2*((SpecC(w)*ln(\frac{SpecC(w)}{E_1})) + (RefC(w)*ln(\frac{RefC(w)}{E_2})))$

# %% [markdown]
# #### $E_i = \frac{N_i*\sum(O_i)}{\sum(N_i)}$

# %% [markdown]
# $w$ - слово
#
# $SpecC(w)$ –  частота слова в тематическом корпусе;
#
# $RefC(w)$ –  частота слова в контрастном корпусе;

# %%
df['LogLikelihood'] = pd.Series([loglikelihood.llr(numpy.matrix([[df.loc[df['word'] == i, 'word freq in SpecC'].iloc[0], 
                                                                df.loc[df['word'] == i, 'word freq in RefC'].iloc[0]], 
                                                                [df.loc[df['word'] == i, 'not word freq in SpecC'].iloc[0], 
                                                                df.loc[df['word'] == i, 'not word freq in RefC'].iloc[0]]])) 
                                 for i in df['word']])

# %%
df_llh = df.sort_values(by=['LogLikelihood'], ascending=False)
df_llh = df_llh.reset_index(drop=True)

# %% [markdown]
# Топ-10 ключевых слов:

# %%
df_llh[:10]
# Out:
#         word  word freq in RefC  word freq in SpecC  word freq in C  \
# 0       брак                  1                 137             138
# 1     любовь                  5                  57              62
# 2        муж                 11                  64              75
# 3        бог                 11                  61              72
# 4    ребёнок                 22                  82             104
# 5    должный                  9                  53              62
# 6       жена                 27                  73             100
# 7        дух                  2                  22              24
# 8  семейство                  2                  20              22
# 9     супруг                  2                  20              22
#
#    not word freq in RefC  not word freq in SpecC  not word freq in C  \
# 0                   6060                    5792               11852
# 1                   6056                    5872               11928
# 2                   6050                    5865               11915
# 3                   6050                    5868               11918
# 4                   6039                    5847               11886
# 5                   6052                    5876               11928
# 6                   6034                    5856               11890
# 7                   6059                    5907               11966
# 8                   6059                    5909               11968
# 9                   6059                    5909               11968
#
#    expected freq in SpecC  expected freq in RefC  LogLikelihood   Weirdness
# 0               68.240367              69.759633      13.567193  140.050093
# 1               30.658716              31.341284       7.250727   11.653803
# 2               37.087156              37.912844       6.546671    5.947715
# 3               35.603670              36.396330       6.291246    5.668916
# 4               51.427523              52.572477       6.204635    3.810255
# 5               30.658716              31.341284       5.977486    6.019996
# 6               49.449541              50.550459       4.815526    2.763897
# 7               11.867890              12.132110       4.469961   11.244898
# 8               10.878899              11.121101       4.185846   10.222635
# 9               10.878899              11.121101       4.185846   10.222635

# %% [markdown]
# Топ-10 неключевых слов:

# %%
df_llh[-10:]
# Out:
#              word  word freq in RefC  word freq in SpecC  word freq in C  \
# 3818  присутствие                 14                   1              15
# 3819      сделать                 23                   4              27
# 3820        дверь                 15                   1              16
# 3821     понимать                 15                   1              16
# 3822           ах                 16                   1              17
# 3823        место                 17                   1              18
# 3824         лицо                 38                   9              47
# 3825         глаз                 22                   2              24
# 3826         брат                 34                   4              38
# 3827         рука                 35                   3              38
#
#       not word freq in RefC  not word freq in SpecC  not word freq in C  \
# 3818                   6047                    5928               11975
# 3819                   6038                    5925               11963
# 3820                   6046                    5928               11974
# 3821                   6046                    5928               11974
# 3822                   6045                    5928               11973
# 3823                   6044                    5928               11972
# 3824                   6023                    5920               11943
# 3825                   6039                    5927               11966
# 3826                   6027                    5925               11952
# 3827                   6026                    5926               11952
#
#       expected freq in SpecC  expected freq in RefC  LogLikelihood  Weirdness
# 3818                7.417431               7.582569      -3.629854   0.073019
# 3819               13.351376              13.648624      -3.793678   0.177785
# 3820                7.911927               8.088073      -3.795920   0.068151
# 3821                7.911927               8.088073      -3.795920   0.068151
# 3822                8.406422               8.593578      -3.956095   0.063891
# 3823                8.900917               9.099083      -4.110949   0.060133
# 3824               23.241284              23.758716      -4.322456   0.242115
# 3825               11.867890              12.132110      -4.370128   0.092933
# 3826               18.790826              19.209174      -5.150025   0.120266
# 3827               18.790826              19.209174      -5.574238   0.087623

# %% [markdown]
# Применим статистику **Weirdness**.

# %% [markdown]
# #### $Weirdness (w) =  \frac{SpecC(w)}{|SpeC|} * {\frac{|RefC|}{RefC(w)}}$

# %% [markdown]
# $w$ - слово
#
# $SpecC(w)$ –  частота слова в тематическом корпусе
#
# $|SpecC|$ – объём тематического корпуса
#
# $RefC(w)$ –  частота слова в контрастном корпусе
#
# $|RefC|$ – объём контрастного корпуса

# %%
df['Weirdness'] = (df['word freq in SpecC'] / lenSpecC) / (df['word freq in RefC'] / lenRefC)

# %%
df_weird = df.sort_values(by=['Weirdness'], ascending=False)[df.Weirdness != numpy.inf]
df_weird = df_weird[df_weird.Weirdness != 0.0]
df_weird = df_weird.reset_index(drop=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_weird[:10]
# Out:
#           word  word freq in RefC  word freq in SpecC  word freq in C  \
# 0         брак                  1                 137             138
# 1     семейный                  1                  14              15
# 2       любовь                  5                  57              62
# 3         сила                  1                  11              12
# 4          дух                  2                  22              24
# 5       супруг                  2                  20              22
# 6  становиться                  1                  10              11
# 7      господь                  2                  20              22
# 8         цель                  1                  10              11
# 9    семейство                  2                  20              22
#
#    not word freq in RefC  not word freq in SpecC  not word freq in C  \
# 0                   6060                    5792               11852
# 1                   6060                    5915               11975
# 2                   6056                    5872               11928
# 3                   6060                    5918               11978
# 4                   6059                    5907               11966
# 5                   6059                    5909               11968
# 6                   6060                    5919               11979
# 7                   6059                    5909               11968
# 8                   6060                    5919               11979
# 9                   6059                    5909               11968
#
#    expected freq in SpecC  expected freq in RefC  LogLikelihood   Weirdness
# 0               68.240367              69.759633      13.567193  140.050093
# 1                7.417431               7.582569       3.707972   14.311688
# 2               30.658716              31.341284       7.250727   11.653803
# 3                5.933945               6.066055       3.159381   11.244898
# 4               11.867890              12.132110       4.469961   11.244898
# 5               10.878899              11.121101       4.185846   10.222635
# 6                5.439450               5.560550       2.958665   10.222635
# 7               10.878899              11.121101       4.185846   10.222635
# 8                5.439450               5.560550       2.958665   10.222635
# 9               10.878899              11.121101       4.185846   10.222635

# %%
df_weird[-10:]
# Out:
#             word  word freq in RefC  word freq in SpecC  word freq in C  \
# 531         брат                 34                   4              38
# 532   совершенно                  9                   1              10
# 533         глаз                 22                   2              24
# 534         рука                 35                   3              38
# 535     подумать                 13                   1              14
# 536  присутствие                 14                   1              15
# 537     понимать                 15                   1              16
# 538        дверь                 15                   1              16
# 539           ах                 16                   1              17
# 540        место                 17                   1              18
#
#      not word freq in RefC  not word freq in SpecC  not word freq in C  \
# 531                   6027                    5925               11952
# 532                   6052                    5928               11980
# 533                   6039                    5927               11966
# 534                   6026                    5926               11952
# 535                   6048                    5928               11976
# 536                   6047                    5928               11975
# 537                   6046                    5928               11974
# 538                   6046                    5928               11974
# 539                   6045                    5928               11973
# 540                   6044                    5928               11972
#
#      expected freq in SpecC  expected freq in RefC  LogLikelihood  Weirdness
# 531               18.790826              19.209174      -5.150025   0.120266
# 532                4.944954               5.055046      -2.681705   0.113585
# 533               11.867890              12.132110      -4.370128   0.092933
# 534               18.790826              19.209174      -5.574238   0.087623
# 535                6.922936               7.077064      -3.457222   0.078636
# 536                7.417431               7.582569      -3.629854   0.073019
# 537                7.911927               8.088073      -3.795920   0.068151
# 538                7.911927               8.088073      -3.795920   0.068151
# 539                8.406422               8.593578      -3.956095   0.063891
# 540                8.900917               9.099083      -4.110949   0.060133

# %%
print(list(df_weird.word).index('сделать'))
print(list(df_weird.word).index('лицо'))
# Out:
# 523
# 510
