# %% [markdown]
# # RAKE

# %% [markdown]
# **Task 1**: to compare two lists of keywords get from the text in two ways (manually and with Rake algorithm).
# **Task 2**: to improve Rake algorithm.
# **Task 3**: check Rake algorithm on Russian texts
#
# Text is given from: http://www.bbc.com/news/business-43032542

# %%
import RAKE
import operator
import io
import pandas as pd

# %%
stoppath = "SmartStoplist.txt"

# %%
#initialize RAKE by providing a path to a stopwords file
rake_object = RAKE.Rake(stoppath)

# %%
#run on RAKE on a given text
sample_file = io.open("Fish_farming.txt", 'r',encoding="utf-8")
text = sample_file.read()

# %% [markdown]
# 15 manually marked keywords (person 1):

# %%
keywords1 = pd.read_csv("keywords_person1_top15.csv", encoding='utf-8')

# %%
keywords1['len1'] = pd.Series(len(i.split()) for i in keywords1['KeyWord_Nastya'])

# %%
keywords1
# Out:
#                           KeyWord_Nastya  len1
# 0                      tech firm CageEye     3
# 1                   Norwegian fish farms     3
# 2              automated feeding systems     3
# 3   artificial intelligence technologies     3
# 4                     monitor the salmon     3
# 5                        detect sea lice     3
# 6                           fish farming     2
# 7                          farmed salmon     2
# 8                          Mr Sovegjarto     2
# 9                        fish monitoring     2
# 10                              industry     1
# 11                                Norway     1
# 12                                salmon     1
# 13                                  fish     1
# 14                               hi-tech     1

# %% [markdown]
# 15 manually marked keywords (person 2):

# %%
keywords2 = pd.read_csv("keywords_person2_top15.csv", encoding='utf-8')

# %%
keywords2['len2'] = pd.Series(len(i.split()) for i in keywords2['KeyWord_Masha'])

# %%
key_words = pd.concat([keywords1, keywords2], axis=1)
key_words
# Out:
#                           KeyWord_Nastya  len1              KeyWord_Masha  \
# 0                      tech firm CageEye     3               fish farming
# 1                   Norwegian fish farms     3      hydro-acoustic system
# 2              automated feeding systems     3          tech firm CageEye
# 3   artificial intelligence technologies     3               caged salmon
# 4                     monitor the salmon     3       Norwegian fish farms
# 5                        detect sea lice     3    salmon feeding patterns
# 6                           fish farming     2  automated fish monitoring
# 7                          farmed salmon     2        monitor the salmon
# 8                          Mr Sovegjarto     2      feeding fish visually
# 9                        fish monitoring     2     the parasitic sea lice
# 10                              industry     1            detect sea lice
# 11                                Norway     1               lice removal
# 12                                salmon     1             salmon farmers
# 13                                  fish     1   farmed salmon production
# 14                               hi-tech     1     high-tech technologies
#
#     len2
# 0      2
# 1      2
# 2      3
# 3      2
# 4      3
# 5      3
# 6      3
# 7      3
# 8      3
# 9      4
# 10     3
# 11     2
# 12     2
# 13     3
# 14     2

# %% [markdown]
# Thus, we get ~0.27% coincidence between two undependently marked keyword lists (4/15 words).

# %% [markdown]
# Let's also count an agreement of annotators. To be able to do it we need to encode strings as numbers first.

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
le = preprocessing.LabelEncoder()
le.fit(pd.Series(list(key_words['KeyWord_Nastya']) + list(key_words['KeyWord_Masha'])))
KeyWords_Nastya_le = le.transform(key_words['KeyWord_Nastya'])
KeyWords_Masha_le = le.transform(key_words['KeyWord_Masha'])

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(KeyWords_Nastya_le, KeyWords_Masha_le)
# Out:
# -0.018099547511312153

# %% [markdown]
# Kappa score is -.01 which means no agreement. There is no surprise cause even having common keywords it's impossible to put them into the same order which kappa score is based on as well.

# %%
#fing keywords with max word length 3
keywords_rake_1 = rake_object.run(text, maxWords = 3)

# %%
len(keywords_rake_1)
# Out:
# 155

# %%
print("Keywords:")
for word in keywords_rake_1:
    print(word)
# Out:
# Keywords:
# ('7m-10m krone', 9.0)
# ('hi-tech approaches', 9.0)
# ('perennially problematic visitor', 9.0)
# ('self-guided tool', 9.0)
# ('hi-tech solutions', 9.0)
# ('mr shang hopes', 8.5)
# ('salmon prices soaring', 8.1)
# ('salmon sloshing loudly', 8.1)
# ('de-loused salmon', 8.1)
# ('believes mr sovegjarto', 8.0)
# ('humans simply overseeing', 8.0)
# ('artificial intelligence technologies', 8.0)
# ('computers carefully monitor', 8.0)
# ('parasitic sea louse', 8.0)
# ('tech firm cageeye', 7.75)
# ('hydro-acoustic system', 7.6)
# ('un-gobbled feed', 7.6)
# ('lingalaks fish farms', 7.25)
# ('modern fish farms', 7.25)
# ('automated fish monitoring', 7.0)
# ('feeding fish visually', 7.0)
# ('artificial intelligence', 5.0)
# ('mr sovegjarto', 5.0)
# ('mr folkedal', 4.5)
# ('fish farms', 4.25)
# ('farmed salmon', 4.1)
# ('million salmon', 4.1)
# ('caged salmon', 4.1)
# ('salmon farming', 4.1)
# ('fish farming', 4.0)
# ('big business', 4.0)
# ('100 million tonnes', 4.0)
# ('boost production', 4.0)
# ('cut costs', 4.0)
# ('feeding frenzy', 4.0)
# ('improve [expenditure]', 4.0)
# ('pellet detector', 4.0)
# ('wrong place', 4.0)
# ('ole folkedal', 4.0)
# ('marine research', 4.0)
# ('oxygen levels', 4.0)
# ('giving scientists', 4.0)
# ('factors influencing', 4.0)
# ('huge variations', 4.0)
# ('recently raised $3', 4.0)
# ('video cameras', 4.0)
# ('site watching', 4.0)
# ('causing damage', 4.0)
# ('fish inedible', 4.0)
# ('removed manually', 4.0)
# ('fish make', 3.75)
# ('firm lots', 3.75)
# ('make decisions', 3.75)
# ('make big', 3.75)
# ('water currents', 3.666666666666667)
# ('water temperature', 3.666666666666667)
# ('system listens', 3.6)
# ('reduced feed', 3.6)
# ('salmon farmers', 3.6)
# ('noise lessens', 3.5)
# ('aquabyte founder', 3.5)
# ('stick cctv', 3.5)
# ('lice attach', 3.5)
# ('lice removal', 3.5)
# ('fires lasers', 3.5)
# ('fatal result', 3.5)
# ('audio data', 3.333333333333333)
# ('lucrative industry', 3.333333333333333)
# ('farms', 2.25)
# ('salmon', 2.1)
# ('fish', 2.0)
# ('feeding', 2.0)
# ('monitor', 2.0)
# ('humans', 2.0)
# ('automated', 2.0)
# ('louse', 2.0)
# ('firm', 1.75)
# ('make', 1.75)
# ('water', 1.6666666666666667)
# ('feed', 1.6)
# ('system', 1.6)
# ('lasers', 1.5)
# ('noise', 1.5)
# ('farmers', 1.5)
# ('aquabyte', 1.5)
# ('cctv', 1.5)
# ('fatal', 1.5)
# ('lice', 1.5)
# ('industry', 1.3333333333333333)
# ('data', 1.3333333333333333)
# ('produces', 1.0)
# ('year', 1.0)
# ('producers', 1.0)
# ('turning', 1.0)
# ('automation', 1.0)
# ('eat', 1.0)
# ('norway', 1.0)
# ('produce', 1.0)
# ('installed', 1.0)
# ('cluster', 1.0)
# ('swim', 1.0)
# ('knowledge', 1.0)
# ('save', 1.0)
# ('money', 1.0)
# ('wasted', 1.0)
# ('developed', 1.0)
# ('years', 1.0)
# ('develop', 1.0)
# ('observes', 1.0)
# ('number', 1.0)
# ('pellets', 1.0)
# ('full', 1.0)
# ('accurate', 1.0)
# ('technology', 1.0)
# ('institute', 1.0)
# ('bergen', 1.0)
# ('insights', 1.0)
# ('day', 1.0)
# ('adds', 1.0)
# ('process', 1.0)
# ('rise', 1.0)
# ('start', 1.0)
# ('set', 1.0)
# ('start-', 1.0)
# ('5m', 1.0)
# ('makes', 1.0)
# ('cages', 1.0)
# ('pens', 1.0)
# ('operators', 1.0)
# ('determining', 1.0)
# ('explains', 1.0)
# ('images', 1.0)
# ('approach', 1.0)
# ('group', 1.0)
# ('designed', 1.0)
# ('future', 1.0)
# ('stingray', 1.0)
# ('destroy', 1.0)
# ('hit', 1.0)
# ('coagulates', 1.0)
# ('milliseconds', 1.0)
# ('boasts', 1.0)
# ('company', 1.0)
# ('website', 1.0)
# ('mirror-', 1.0)
# ('skin', 1.0)
# ('reflects', 1.0)
# ('laser', 1.0)
# ('swims', 1.0)
# ('unharmed', 1.0)
# ('surprise', 1.0)
# ('wealthy', 1.0)
# ('5%', 0)
# ('｣2', 0)
# (']', 0)

# %% [markdown]
# Not really keywords due to my introspection:
#
# 7m-10m krone;
# perennially problematic visitor;
# salmon prices soaring;
# humans simply overseeing;
# mr shang hopes;
# believes mr sovegjarto;
# million salmon;
# big business;
# 100 million tonnes;
# boost production;
# feeding frenzy;
# improve [expenditure];
# pellet detector;
# wrong place;
# giving scientists;
# huge variations;
# factors influencing;
# recently raised $3;
# causing damage;
# removed manually;
# fish make;
# firm lots;
# make decisions;
# make big;
# water currents;
# water temperature;
# fires lasers;
# fatal result;
# monitor;
# humans;
# make;
# water;
# system;
# fatal;
# data;
# produces;
# year;
# producers;
# turning;
# eat;
# produce;
# installed;
# cluster;
# swim;
# knowledge;
# save;
# money;
# wasted;
# developed;
# years;
# develop;
# observes;
# number;
# pellets;
# full;
# accurate;
# institute;
# bergen;
# insights;
# day;
# adds;
# process;
# rise;
# start;
# set;
# start-;
# 5m;
# makes;
# pens;
# operators;
# determining;
# explains;
# approach;
# group;
# designed;
# stingray;
# hit;
# coagulates;
# milliseconds;
# boasts;
# website;
# mirror-;
# skin;
# reflects;
# swims;
# surprise;
# wealthy;
# 5%;
# ｣2;
# ];

# %% [markdown]
# **Results**:
#
# The text is about IT-technologies in fishing.
# 155 keyword expression with maximal length equal to 3 is found in text with 624 words.
#
# Almost all manually marked keywords are found (although I'd add 'salmon feeding patterns', 'Norway', 'automated feeding systems', 'fish monitoring' and 'computer vision algorithms').
#
# Still there is quite a lot of trash (the accuracy is nearly 0.58%: 90 keywords are really keywords): mostly because of lonely words that are specific maybe (like 'monitor') but not really reflect the sense of the text alone while including them in ngrams helps (compare 'monitor' with 'fish monitoring').
#
# If we take top-15 rake keywords (still with max length 3) then the intersection with GS is only 4 expressions (0.27%):  'hi-tech approaches', 'artificial intelligence technologies', 'tech firm cageeye' and 'parasitic sea louse'.
# Although except for several totally not key expressions ('7m-10m krone' and 'perennially problematic visitors') it's still more or less about the same but not exactly. For example: it's important to include to keywords personalities that are mentioned in article ('mr shang') but there is no need to include a verb within it (compare 'mr shang' and 'mr shang hopes', 'mr sovergjarto' and 'believes mr sovegjarto'). Similarly, 'salmon' itself should be included in keywords cause the whole text is about the salmon while 'salmon sloshing loudly' is not really key expression (adverb is definutely unnecessary and sloshing is not the main topic of text as well).
#
# I don't think there are any crucially necessary expressions that were not included in the GS.

# %%
('7m-10m krone', 9.0)
('hi-tech approaches', 9.0)
('perennially problematic visitor', 9.0)
('self-guided tool', 9.0)
('hi-tech solutions', 9.0)
('mr shang hopes', 8.5)
('salmon prices soaring', 8.1)
('salmon sloshing loudly', 8.1)
('de-loused salmon', 8.1)
('believes mr sovegjarto', 8.0)
('humans simply overseeing', 8.0)
('artificial intelligence technologies', 8.0)
('computers carefully monitor', 8.0)
('parasitic sea louse', 8.0)
('tech firm cageeye', 7.75)

# %% [markdown]
# ### Rake 2.0

# %% [markdown]
# 1. В алгоритм можно добавить лемматизацию слов
# 2. Можно выставить минимальную длину слова 3, тогда не будет мусора (5% / ｣2 / ] / 5m)
#
# P.S. Увеличение порога минимальной встречаемости приводит к тому, что ключевых выражений очень мало и одни однословные.

# %%
#fing keywords with max word length 3
keywords = rake_object.run(text, maxWords = 3, minCharacters=3, minFrequency=2)

# %%
keywords
# Out:
# [('salmon', 2.1),
#  ('fish', 2.0),
#  ('firm', 1.75),
#  ('feed', 1.6),
#  ('system', 1.6),
#  ('lice', 1.5),
#  ('industry', 1.3333333333333333),
#  ('data', 1.3333333333333333),
#  ('year', 1.0),
#  ('turning', 1.0),
#  ('eat', 1.0),
#  ('developed', 1.0),
#  ('technology', 1.0)]

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()
words = RAKE.RAKE.separate_words(text)
lemmas = [wordnet_lemmatizer.lemmatize(word) for word in words]
lemmatized_text = ' '.join(lemmas)

# %%
#fing keywords with max word length 3
keywords_rake_2 = rake_object.run(lemmatized_text, maxWords = 3)

# %%
len(keywords_rake_2)
# Out:
# 127

# %%
'video camera' in [i[0] for i in keywords_rake_2]
# Out:
# True

# %%
keywords2
# Out:
# [('7m 10m krone', 9.0),
#  ('human simply overseeing', 9.0),
#  ('computer vision algorithm', 9.0),
#  ('perennially problematic visitor', 9.0),
#  ('future stingray ha', 8.333333333333334),
#  ('salmon sloshing loudly', 8.0),
#  ('de loused salmon', 8.0),
#  ('hydro acoustic system', 7.8),
#  ('lingalaks fish farm', 7.25),
#  ('make big change', 7.25),
#  ('modern fish farm', 7.25),
#  ('artificial intelligence technology', 7.0),
#  ('automated fish monitoring', 7.0),
#  ('feeding fish visually', 7.0),
#  ('artificial intelligence', 5.0),
#  ('big business', 4.5),
#  ('ha installed', 4.333333333333334),
#  ('technology ha', 4.333333333333334),
#  ('fish farm', 4.25),
#  ('fish farming', 4.0),
#  ('million tonne', 4.0),
#  ('laser automation', 4.0),
#  ('boost production', 4.0),
#  ('cut cost', 4.0),
#  ('farmed salmon', 4.0),
#  ('million salmon', 4.0),
#  ('feeding frenzy', 4.0),
#  ('improve expenditure', 4.0),
#  ('wrong place', 4.0),
#  ('caged salmon', 4.0),
#  ('ole folkedal', 4.0),
#  ('marine research', 4.0),
#  ('oxygen level', 4.0),
#  ('giving scientist', 4.0),
#  ('factor influencing', 4.0),
#  ('huge variation', 4.0),
#  ('mr folkedal', 4.0),
#  ('salmon farming', 4.0),
#  ('tech approach', 4.0),
#  ('video camera', 4.0),
#  ('aquabyte founder', 4.0),
#  ('site watching', 4.0),
#  ('causing damage', 4.0),
#  ('fish inedible', 4.0),
#  ('removed manually', 4.0),
#  ('guided tool', 4.0),
#  ('fire laser', 4.0),
#  ('millisecond boast', 4.0),
#  ('tech solution', 4.0),
#  ('system listens', 3.8),
#  ('make decision', 3.75),
#  ('water current', 3.666666666666667),
#  ('water temperature', 3.666666666666667),
#  ('stick cctv', 3.5),
#  ('fatal result', 3.5),
#  ('laser swim', 3.5),
#  ('salmon farmer', 3.5),
#  ('firm lot', 3.333333333333333),
#  ('audio data', 3.333333333333333),
#  ('lucrative industry', 3.333333333333333),
#  ('system developed', 3.3),
#  ('reduced feed', 3.25),
#  ('louse removal', 3.25),
#  ('farm', 2.25),
#  ('fish', 2.0),
#  ('feeding', 2.0),
#  ('salmon', 2.0),
#  ('technology', 2.0),
#  ('automated', 2.0),
#  ('system', 1.8),
#  ('make', 1.75),
#  ('water', 1.6666666666666667),
#  ('swim', 1.5),
#  ('developed', 1.5),
#  ('farmer', 1.5),
#  ('cctv', 1.5),
#  ('fatal', 1.5),
#  ('industry', 1.3333333333333333),
#  ('firm', 1.3333333333333333),
#  ('data', 1.3333333333333333),
#  ('feed', 1.25),
#  ('louse', 1.25),
#  ('produce', 1.0),
#  ('year', 1.0),
#  ('turning', 1.0),
#  ('eat', 1.0),
#  ('norway', 1.0),
#  ('cluster', 1.0),
#  ('knowledge', 1.0),
#  ('save', 1.0),
#  ('money', 1.0),
#  ('wasted', 1.0),
#  ('develop', 1.0),
#  ('observes', 1.0),
#  ('number', 1.0),
#  ('pellet', 1.0),
#  ('full', 1.0),
#  ('accurate', 1.0),
#  ('institute', 1.0),
#  ('bergen', 1.0),
#  ('insight', 1.0),
#  ('day', 1.0),
#  ('add', 1.0),
#  ('process', 1.0),
#  ('rise', 1.0),
#  ('start', 1.0),
#  ('set', 1.0),
#  ('monitor', 1.0),
#  ('cage', 1.0),
#  ('pen', 1.0),
#  ('operator', 1.0),
#  ('determining', 1.0),
#  ('explains', 1.0),
#  ('image', 1.0),
#  ('group', 1.0),
#  ('designed', 1.0),
#  ('destroy', 1.0),
#  ('hit', 1.0),
#  ('coagulates', 1.0),
#  ('company', 1.0),
#  ('website', 1.0),
#  ('mirror', 1.0),
#  ('skin', 1.0),
#  ('reflects', 1.0),
#  ('unharmed', 1.0),
#  ('surprise', 1.0),
#  ('wealthy', 1.0)]

# %% [markdown]
# Устойчивые выражения, выбранные стандартным рейком, но не выбранные улучшенным:

# %%
set([i[0] for i in keywords_rake_1]) - set([i[0] for i in keywords_rake_2])
# Out:
# {'100 million tonnes',
#  '5%',
#  '5m',
#  '7m-10m krone',
#  ']',
#  'adds',
#  'approach',
#  'aquabyte',
#  'artificial intelligence technologies',
#  'automation',
#  'believes mr sovegjarto',
#  'boasts',
#  'cages',
#  'computers carefully monitor',
#  'cut costs',
#  'de-loused salmon',
#  'factors influencing',
#  'farmers',
#  'farms',
#  'fires lasers',
#  'firm lots',
#  'fish farms',
#  'fish make',
#  'future',
#  'giving scientists',
#  'hi-tech approaches',
#  'hi-tech solutions',
#  'huge variations',
#  'humans',
#  'humans simply overseeing',
#  'hydro-acoustic system',
#  'images',
#  'improve [expenditure]',
#  'insights',
#  'installed',
#  'laser',
#  'lasers',
#  'lice',
#  'lice attach',
#  'lice removal',
#  'lingalaks fish farms',
#  'make big',
#  'make decisions',
#  'makes',
#  'milliseconds',
#  'mirror-',
#  'modern fish farms',
#  'mr shang hopes',
#  'mr sovegjarto',
#  'noise',
#  'noise lessens',
#  'operators',
#  'oxygen levels',
#  'parasitic sea louse',
#  'pellet detector',
#  'pellets',
#  'pens',
#  'producers',
#  'produces',
#  'recently raised $3',
#  'salmon farmers',
#  'salmon prices soaring',
#  'self-guided tool',
#  'start-',
#  'stingray',
#  'swims',
#  'tech firm cageeye',
#  'un-gobbled feed',
#  'video cameras',
#  'water currents',
#  'years',
#  '｣2'}

# %% [markdown]
# Лемматизатор NLTK сокращает некоторые слова, которые не должна (например, less -> le). Но в целом новый алгоритм оставляет только лемматизированные сочетания, таким образом убирая лишние:
# - 'artificial intelligence technology' вместо 'artificial intelligence technology' и 'artificial intelligence technologies'
# - 'video camera' вместо 'video camera' и 'video cameras'

# %% [markdown]
# ### Rake Russian

# %%
#initialize RAKE by providing a path to a stopwords file
rake_object_russian = RAKE.Rake("stoplist_ru.txt")

# %%
#run on RAKE on a given text
sample_file = io.open("технологии_рыбалка.txt", 'r')
text_ru = sample_file.read()

# %%
#fing keywords with max word length 3
keywords_ru = rake_object_russian.run(text_ru, maxWords = 3)

# %%
keywords_ru
# Out:
# [('первыми занятиями человека', 9.0),
#  ('собирания всяких корешков', 9.0),
#  ('остаются самыми консервативными', 9.0),
#  ('делают орудия труда', 9.0),
#  ('большей частью увлечения', 9.0),
#  ('пошло развитие гаджета', 9.0),
#  ('вооружение рыбаков поступили', 9.0),
#  ('высокая разрешающая способность', 9.0),
#  ('проводить поиск рыбы', 9.0),
#  ('предмет наличия рыбы', 9.0),
#  ('оповещают рыболова писком', 9.0),
#  ('дорогие модели идут', 9.0),
#  ('кучу рыбацких наворотов', 9.0),
#  ('способны воспроизводить звуки', 9.0),
#  ('издаваемые мелкой рыбкой', 9.0),
#  ('электронные донные приманки', 9.0),
#  ('имитация работы жабр', 8.5),
#  ('предлагают беспроводные эхолоты', 8.25),
#  ('эхолоты позволяют работать', 8.25),
#  ('показа технологии ebs', 8.25),
#  ('установить бесплатное приложение', 8.0),
#  ('предметов пользования карпятников', 8.0),
#  ('по-мощью рыбак', 7.666666666666667),
#  ('берегу появятся рыбаки', 7.166666666666667),
#  ('рыбаки карпятники', 4.5),
#  ('имитация рачка', 4.5),
#  ('ebs original', 4.25),
#  ('ebs™ craw', 4.25),
#  ('ebs™ shad', 4.25),
#  ('учебников истории', 4.0),
#  ('смену лещиновым', 4.0),
#  ('деревянной палочкой', 4.0),
#  ('способом выживания', 4.0),
#  ('первом месте', 4.0),
#  ('навигационный прибор', 4.0),
#  ('управляющий катером', 4.0),
#  ('моторной лодкой', 4.0),
#  ('подводных препятствиях', 4.0),
#  ('крупную рыбу', 4.0),
#  ('стаи маленькой', 4.0),
#  ('двум бортам', 4.0),
#  ('дисплее рисуется', 4.0),
#  ('производители пошли', 4.0),
#  ('которое работает', 4.0),
#  ('шарообразной формы', 4.0),
#  ('помощью удилища', 4.0),
#  ('пути следования', 4.0),
#  ('вода стоячая', 4.0),
#  ('пятном прикормки', 4.0),
#  ('дальность действия', 4.0),
#  ('втором месте', 4.0),
#  ('завоза привад', 4.0),
#  ('дистанционным радиоуправлением', 4.0),
#  ('основные пользователи', 4.0),
#  ('основная задача', 4.0),
#  ('доставка прикормки', 4.0),
#  ('рыбаку место', 4.0),
#  ('радиоуправляемые судна', 4.0),
#  ('прохладном тенечке', 4.0),
#  ('изучать водоем', 4.0),
#  ('сигнализаторы поклевки', 4.0),
#  ('ловли карпа', 4.0),
#  ('сигнализаторы срабатывают', 4.0),
#  ('поклевке карпа', 4.0),
#  ('цветовой индикацией', 4.0),
#  ('поисках приключений', 4.0),
#  ('гипнотизировать колокольчик', 4.0),
#  ('противоугонную систему', 4.0),
#  ('настоящую рыбу', 4.0),
#  ('погремушки внутри', 4.0),
#  ('верхом развития', 4.0),
#  ('процессе изготовления', 4.0),
#  ('момент паники', 4.0),
#  ('немножко эволюции', 4.0),
#  ('переключая режимы', 4.0),
#  ('зимние удочки', 4.0),
#  ('милыми названием', 4.0),
#  ('играть приманкой', 4.0),
#  ('разной частотой', 4.0),
#  ('вместо удочек', 4.0),
#  ('вместо улова', 4.0),
#  ('приносить селфи', 4.0),
#  ('находятся эхолоты', 3.75),
#  ('позволяет отображать', 3.5),
#  ('приборы имеют', 3.5),
#  ('эхолоты', 2.25),
#  ('предметов', 2.0),
#  ('установить', 2.0),
#  ('берегу', 1.6666666666666667),
#  ('рыбак', 1.6666666666666667),
#  ('приборы', 1.5),
#  ('отображать', 1.5),
#  ('находятся', 1.5),
#  ('помним', 1.0),
#  ('охота', 1.0),
#  ('рыбалка', 1.0),
#  ('грибов', 1.0),
#  ('меняются', 1.0),
#  ('материалы', 1.0),
#  ('грибы', 1.0),
#  ('собираем', 1.0),
#  ('помогая', 1.0),
#  ('тысячу', 1.0),
#  ('правда', 1.0),
#  ('занятия', 1.0),
#  ('видеть', 1.0),
#  ('узнавать', 1.0),
#  ('оказалось', 1.0),
#  ('направлении', 1.0),
#  ('рисующие', 1.0),
#  ('сонары', 1.0),
#  ('курсу', 1.0),
#  ('неплохо', 1.0),
#  ('ios 5', 1.0),
#  ('эхолот', 1.0),
#  ('забрасывается', 1.0),
#  ('контролировать', 1.0),
#  ('эффективность', 1.0),
#  ('40 метров', 1.0),
#  ('кораблики', 1.0),
#  ('прикормок', 1.0),
#  ('ставится', 1.0),
#  ('корабликами', 1.0),
#  ('оснастки', 1.0),
#  ('любое', 1.0),
#  ('понравившееся', 1.0),
#  ('устанавливать', 1.0),
#  ('позволит', 1.0),
#  ('сидя', 1.0),
#  ('комплекте', 1.0),
#  ('пейджером', 1.0),
#  ('бродить', 1.0),
#  ('сидеть', 1.0),
#  ('знаем', 1.0),
#  ('воблер', 1.0),
#  ('кратко', 1.0),
#  ('деревянная', 1.0),
#  ('расцветок', 1.0),
#  ('бусинки', 1.0),
#  ('десяток', 1.0),
#  ('прошло', 1.0),
#  ('воблеры', 1.0),
#  ('применяется', 1.0),
#  ('технология', 1.0),
#  ('бегства', 1.0),
#  ('заводит', 1.0),
#  ('хищника', 1.0),
#  ('чип', 1.0),
#  ('решить', 1.0),
#  ('пищит', 1.0),
#  ('приманка', 1.0),
#  ('режим', 1.0),
#  ('звука', 1.0),
#  ('приманке', 1.0),
#  ('батарейки', 1.0),
#  ('кибердроч -2', 1.0),
#  ('самотряс', 1.0),
#  ('самостоятельно', 1.0),
#  ('причем', 1.0),
#  ('каких', 1.0),
#  ('червей', 1.0),
#  ('дне', 1.0),
#  ('осталось', 1.0),
#  ('смартфоны', 1.0),
#  ('домой', 1.0),
#  ('карасями', 1.0),
#  ('\ufeff', 0),
#  ('3+', 0),
#  ('0+', 0)]

# %% [markdown]
# Текст примерно на одну и ту же тему, что и английский - про инноваицонные технологии в рабылке.
#
# Ключевые биграммы и триграммы в русском тексте rake находит гораздо хуже. Похоже, что в русском тройные коллокации, в отличие от английского, в принципе менее устойчивы и реже употребляются вместе, можно ограничить максимальное количество слов двумя.
#
# Особенно выделяются ненужные сочетания с глаголами и случайными прямыме объектами (например, "изучать водоём") и предложные группы ("вместо удочек", "вместо улова"), поэтому хорошо бы учиывать часть речи. Но встречаются и подходящие: навигационный прибор, крупная рыба.
#
# Отдельные слова в русском все же лучше отражают смысл текста. Но лучше подключить лемматизацию, чтобы не повторялись словоформы одной и той же лексемы, это бы помогло исключить стоп-слова в любых формах, а не только в тех, что указаны в стоп-листе (например, местоимения "каких", "любое").
